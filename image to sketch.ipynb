# %% [markdown]
# <a href="https://colab.research.google.com/github/ravya26/OIBSIP-LandingPage/blob/main/image%20to%20sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Define the correct image path
img_path = "/content/girl.jpg"

# Read the uploaded image
img = cv2.imread(img_path)

# Check if the image is loaded correctly
if img is None:
    print("Error: Unable to load image. Please check the file path or format.")
else:
    # Convert to RGB for displaying
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the original image
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title('Original Image')
    plt.show()

# %%
# Convert to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Display grayscale image
plt.imshow(gray_img, cmap='gray')
plt.axis('off')
plt.title('Grayscale Image')
plt.show()

# %%
# Invert the grayscale image
inverted_img = 255 - gray_img

# Display inverted image
plt.imshow(inverted_img, cmap='gray')
plt.axis('off')
plt.title('Inverted Image')
plt.show()

# %%
# Apply Gaussian Blur to the inverted image
blur_img = cv2.GaussianBlur(inverted_img, (21, 21), 0)

# Display blurred image
plt.imshow(blur_img, cmap='gray')
plt.axis('off')
plt.title('Blurred Image')
plt.show()

# %%
# Invert the blurred image
inverted_blur = 255 - blur_img

# Display the inverted blur
plt.imshow(inverted_blur, cmap='gray')
plt.axis('off')
plt.title('Inverted Blur')
plt.show()

# %%
# Create the sketch using dodge blend
sketch_img = cv2.divide(gray_img, inverted_blur, scale=256.0)

# Display the final sketch
plt.imshow(sketch_img, cmap='gray')
plt.axis('off')
plt.title('Pencil Sketch')
plt.show()
